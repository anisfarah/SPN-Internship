# %%
# !pip install surya-ocr
# Out:
# Requirement already satisfied: surya-ocr in /usr/local/lib/python3.10/dist-packages (0.4.14)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (1.2.0)
# Requirement already satisfied: ftfy<7.0.0,>=6.1.3 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (6.2.0)
# Requirement already satisfied: opencv-python<5.0.0.0,>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (4.10.0.84)
# Requirement already satisfied: pillow<11.0.0,>=10.2.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (2.8.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (2.3.4)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.25.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (4.30.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (1.0.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (0.9.0)
# Requirement already satisfied: torch<3.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (2.3.0+cu121)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (4.41.2)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy<7.0.0,>=6.1.3->surya-ocr) (0.2.13)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python<5.0.0.0,>=4.9.0.80->surya-ocr) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.3->surya-ocr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.3->surya-ocr) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.3->surya-ocr) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3.0.0,>=2.3.0->surya-ocr) (12.5.82)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (0.23.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.3.0->surya-ocr) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.41.0->surya-ocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.41.0->surya-ocr) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.41.0->surya-ocr) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.41.0->surya-ocr) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=2.3.0->surya-ocr) (1.3.0)

# %%
from PIL import Image
from surya.ocr import run_ocr
from surya.model.detection.segformer import load_model as load_det_model, load_processor as load_det_processor
from surya.model.recognition.model import load_model as load_rec_model
from surya.model.recognition.processor import load_processor as load_rec_processor

# %%
langs = ["en","fr"] # Replace with your languages
det_processor, det_model = load_det_processor(), load_det_model()
rec_model, rec_processor = load_rec_model(), load_rec_processor()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/430 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/120M [00:00<?, ?B/s]
# Loaded detection model vikp/surya_det2 on device cuda with dtype torch.float16
# config.json:   0%|          | 0.00/6.91k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.05G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Loaded recognition model vikp/surya_rec on device cuda with dtype torch.float16
# preprocessor_config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]

# %%
image = Image.open("/content/WhatsApp Image 2024-03-15 at 12.22.39 (1).jpeg")
predictions = run_ocr([image], [langs], det_model, det_processor, rec_model, rec_processor)
# Out:
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.83s/it]

# %%
concatenated_text = ''  # Initialize an empty string to accumulate the text

for text_line in predictions[0].text_lines:  # Accessing text_lines from the first OCRResult object
    concatenated_text += text_line.text + ' '  # Concatenate the text from each TextLine object with a space

print(concatenated_text.strip())
# Out:
# 548 comune di forte dei marmi L013_ CORPO POLIZIA MUNICIPALE VIA PROVINCIALE 96 55042 FORTE DEI MARMI (LU) Email: vigili@comunefdm.it AUT. SMA MBPA/CN/ER/0008/2015 29. ΖΩς . DCOPD0116 N. CRON. V/25501Z/2023 swiss premium negoce sa rue arnold winkelried 6 1201 GENEVE SVIZZERA - SUISSE Plaque d'immatriculation GE206608 — registre n° 18514/2023 — année de l'infraction 2023 procès-verbal n° V/25501Z/2023 PROCES-VERBAL DE VIOLATION concernant des infractions au Code de la Route commises en Italie (D. Lgs. n° 285 du 30 avril 1992 et ses modifications et intégrations successives) Le conducteur du yéhicule immatriculé : GE206608 type: voiture le: 13/06/2023 à l'heure 18:18 à VIA PIAVE dans la commune de FORTE DEI MARMI a fait l'objet d'une infraction à l'/aux article(s) : 7/9-14 du Code de la Route italien, car: Le jour 13/06/2023 à 18:18 heures à FORTE DEI MARMI - VIA PIAVE, le conducteur non identifié du véhicule voiture plaque d'immatriculation GE206608, passant par le passage de VIA PIAVE, a circulé dans le zone de circulation  sans respecter l'interdiction de transit imposée par les panneaux verticaux et sans en avoir le droit, en violation de l'art. 7 par. 9 et 14 du code de la route  (D.L.vo n.285/92). La constation de la violation a été faite par AG. P.M. Mat. 333 MORICONI FRANCESCA le 07/07/2023 à 10:03 heures sur la base de la documentation produite par le système installé à poste fixe appelé CEYECLOPS matr. 2128002089, agréé par le Ministère des Infrastructures et des Transports avec décrets exécutifs 06/10/2006 prot. 154, 15/07/2008 prot. n.58500 et 30/07/2008 prot. 63604 de Wavelet Thecnology S.p.a. transféré à la société Bridge 129 S.p.a. avec décret n.9942 du 02/02/2009 et avec extension du décret d'homologation n.14 du 03/01/2012. Données personnelles du titulaire du véhicule/plaque d'immatriculation - Nom du transgresseur/Locataire: SWISS PREMIUM NEGOCE SA - Rue, numéro adresse et résidence (pays et ville):  RUE ARNOLD WINKELRIED 6 - 1201 GENEVE - Pays: Svizzera - Suisse Date de réouverture des délais pour la notification: 31/10/2023 Motif de la non-contestation: Section de route sans obligation de réprimander immédiatement la violation. Contrôle effectué ,avec de dispositives électroniquues. L'(les) agent(s) verbalisateur(s)/: BERTAGNA CIREGIA ILARIA (Matr: 480)
